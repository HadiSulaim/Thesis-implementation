# %%
import cv2
import numpy as np
import os

# %%
import cv2
import numpy as np
import os

def load_image(path):
    image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Error: Could not load image at {path}")
    return image

def calculate_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou = np.sum(intersection) / np.sum(union)
    return iou

# Paths to the ground truth and segmented frames
gt_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\str.bis58"
segmented_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street"

# List of frame filenames
frame_filenames = sorted(os.listdir(gt_folder))

# Threshold for considering an object occluded
iou_threshold = 0.5

# Counter for occluded frames
occluded_frame_count = 0

for frame_filename in frame_filenames:
    gt_path = os.path.join(gt_folder, frame_filename)
    segmented_path = os.path.join(segmented_folder, frame_filename)

    # Load the ground truth and segmented masks
    gt_mask = load_image(gt_path)
    segmented_mask = load_image(segmented_path)

    # Ensure both masks are loaded
    if gt_mask is None or segmented_mask is None:
        continue

    # Calculate IoU
    iou = calculate_iou(gt_mask > 0, segmented_mask > 0)

    # Determine occlusion
    if iou < iou_threshold:
        occluded_frame_count += 1

print(f"Number of occluded frames: {occluded_frame_count}")
# Out:
# Error: Could not load image at C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street\00000.jpg
# Error: Could not load image at C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street\00001.jpg
# Error: Could not load image at C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street\00002.jpg
# Error: Could not load image at C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street\00003.jpg
# Error: Could not load image at C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street\00004.jpg
# ...

# %%
import cv2
import numpy as np
import os

def load_image(path):
    image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Error: Could not load image at {path}")
    return image

def calculate_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou = np.sum(intersection) / np.sum(union)
    return iou

# Paths to the ground truth and segmented frames
gt_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\str.bis58"
segmented_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street"

# List of frame filenames
frame_filenames = sorted(os.listdir(gt_folder))

# Print the contents of the directories for debugging
print("Ground Truth Frames:", os.listdir(gt_folder))
print("Segmented Frames:", os.listdir(segmented_folder))

# Threshold for considering an object occluded
iou_threshold = 0.5

# Counter for occluded frames
occluded_frame_count = 0

for frame_filename in frame_filenames:
    gt_path = os.path.join(gt_folder, frame_filename)
    segmented_path = os.path.join(segmented_folder, frame_filename)

    # Load the ground truth and segmented masks
    gt_mask = load_image(gt_path)
    segmented_mask = load_image(segmented_path)

    # Ensure both masks are loaded
    if gt_mask is None or segmented_mask is None:
        continue

    # Calculate IoU
    iou = calculate_iou(gt_mask > 0, segmented_mask > 0)

    # Determine occlusion
    if iou < iou_threshold:
        occluded_frame_count += 1

print(f"Number of occluded frames: {occluded_frame_count}")
# Out:
# Ground Truth Frames: ['00000.jpg', '00001.jpg', '00002.jpg', '00003.jpg', '00004.jpg', '00005.jpg', '00006.jpg', '00007.jpg', '00008.jpg', '00009.jpg', '00010.jpg', '00011.jpg', '00012.jpg', '00013.jpg', '00014.jpg', '00015.jpg', '00016.jpg', '00017.jpg', '00018.jpg', '00019.jpg', '00020.jpg', '00021.jpg', '00022.jpg', '00023.jpg', '00024.jpg', '00025.jpg', '00026.jpg', '00027.jpg', '00028.jpg', '00029.jpg', '00030.jpg', '00031.jpg', '00032.jpg', '00033.jpg', '00034.jpg', '00035.jpg', '00036.jpg', '00037.jpg', '00038.jpg', '00039.jpg', '00040.jpg', '00041.jpg', '00042.jpg', '00043.jpg', '00044.jpg', '00045.jpg', '00046.jpg', '00047.jpg', '00048.jpg', '00049.jpg', '00050.jpg', '00051.jpg', '00052.jpg', '00053.jpg', '00054.jpg', '00055.jpg', '00056.jpg', '00057.jpg', '00058.jpg']
# ...

# %%
import cv2
import numpy as np
import os

def load_image(path):
    image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Error: Could not load image at {path}")
    return image

def calculate_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou = np.sum(intersection) / np.sum(union)
    return iou

# Paths to the ground truth and segmented frames
gt_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\str.bis58"
segmented_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street"

# List of frame filenames
frame_filenames = sorted(os.listdir(gt_folder))

# Threshold for considering an object occluded
iou_threshold = 0.5

# Counter for occluded frames
occluded_frame_count = 0

for frame_filename in frame_filenames:
    gt_path = os.path.join(gt_folder, frame_filename)
    
    # Adjust the filename for the segmented frames
    frame_number = int(frame_filename.split('.')[0])  # Extract the frame number
    segmented_filename = f"frame_{frame_number:04d}.png"  # Match the segmented frame format
    segmented_path = os.path.join(segmented_folder, segmented_filename)

    # Load the ground truth and segmented masks
    gt_mask = load_image(gt_path)
    segmented_mask = load_image(segmented_path)

    # Ensure both masks are loaded
    if gt_mask is None or segmented_mask is None:
        continue

    # Calculate IoU
    iou = calculate_iou(gt_mask > 0, segmented_mask > 0)

    # Determine occlusion
    if iou < iou_threshold:
        occluded_frame_count += 1

print(f"Number of occluded frames: {occluded_frame_count}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 47
#      44     continue
#      46 # Calculate IoU
# ---> 47 iou = calculate_iou(gt_mask > 0, segmented_mask > 0)
#      49 # Determine occlusion
#      50 if iou < iou_threshold:
#
# Cell In[7], line 12, in calculate_iou(mask1, mask2)
#      11 def calculate_iou(mask1, mask2):
# ---> 12     intersection = np.logical_and(mask1, mask2)
#      13     union = np.logical_or(mask1, mask2)
#      14     iou = np.sum(intersection) / np.sum(union)
#
# ValueError: operands could not be broadcast together with shapes (1080,1920) (261,465)

# %%
import cv2
import numpy as np
import os

def load_image(path):
    image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Error: Could not load image at {path}")
    return image

def calculate_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou = np.sum(intersection) / np.sum(union)
    return iou

# Paths to the ground truth and segmented frames
gt_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\str.bis58"
segmented_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street"

# List of frame filenames
frame_filenames = sorted(os.listdir(gt_folder))

# Threshold for considering an object occluded
iou_threshold = 0.5

# Counter for occluded frames
occluded_frame_count = 0

for frame_filename in frame_filenames:
    gt_path = os.path.join(gt_folder, frame_filename)
    
    # Adjust the filename for the segmented frames
    frame_number = int(frame_filename.split('.')[0])  # Extract the frame number
    segmented_filename = f"frame_{frame_number:04d}.png"  # Match the segmented frame format
    segmented_path = os.path.join(segmented_folder, segmented_filename)

    # Load the ground truth and segmented masks
    gt_mask = load_image(gt_path)
    segmented_mask = load_image(segmented_path)

    # Ensure both masks are loaded
    if gt_mask is None or segmented_mask is None:
        continue

    # Resize the segmented mask to match the ground truth mask size
    if gt_mask.shape != segmented_mask.shape:
        segmented_mask = cv2.resize(segmented_mask, (gt_mask.shape[1], gt_mask.shape[0]))

    # Calculate IoU
    iou = calculate_iou(gt_mask > 0, segmented_mask > 0)

    # Determine occlusion
    if iou < iou_threshold:
        occluded_frame_count += 1

print(f"Number of occluded frames: {occluded_frame_count}")
# Out:
# Number of occluded frames: 0

# %%
import cv2
import numpy as np
import os

def load_image(path):
    image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Error: Could not load image at {path}")
    return image

def calculate_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou = np.sum(intersection) / np.sum(union)
    return iou

# Paths to the ground truth and segmented frames
gt_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\str.bis58"
segmented_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street"

# List of frame filenames
frame_filenames = sorted(os.listdir(gt_folder))

# Threshold for considering an object occluded
iou_threshold = 0.5

# Counter for occluded frames
occluded_frame_count = 0

for frame_filename in frame_filenames:
    gt_path = os.path.join(gt_folder, frame_filename)
    
    # Adjust the filename for the segmented frames
    frame_number = int(frame_filename.split('.')[0])  # Extract the frame number
    segmented_filename = f"frame_{frame_number:04d}.png"  # Match the segmented frame format
    segmented_path = os.path.join(segmented_folder, segmented_filename)

    # Load the ground truth and segmented masks
    gt_mask = load_image(gt_path)
    segmented_mask = load_image(segmented_path)

    # Ensure both masks are loaded
    if gt_mask is None or segmented_mask is None:
        continue

    # Resize the segmented mask to match the ground truth mask size
    if gt_mask.shape != segmented_mask.shape:
        segmented_mask = cv2.resize(segmented_mask, (gt_mask.shape[1], gt_mask.shape[0]))

    # Calculate IoU
    iou = calculate_iou(gt_mask > 0, segmented_mask > 0)
    print(f"Frame {frame_filename}: IoU = {iou:.2f}")  # Debugging output

    # Determine occlusion
    if iou < iou_threshold:
        occluded_frame_count += 1

print(f"Number of occluded frames: {occluded_frame_count}")
# Out:
# Frame 00000.jpg: IoU = 1.00
# Frame 00001.jpg: IoU = 1.00
# Frame 00002.jpg: IoU = 1.00
# Frame 00003.jpg: IoU = 1.00
# Frame 00004.jpg: IoU = 1.00
# Frame 00005.jpg: IoU = 1.00
# Frame 00006.jpg: IoU = 1.00
# Frame 00007.jpg: IoU = 1.00
# Frame 00008.jpg: IoU = 1.00
# Frame 00009.jpg: IoU = 1.00
# Frame 00010.jpg: IoU = 1.00
# Frame 00011.jpg: IoU = 1.00
# Frame 00012.jpg: IoU = 1.00
# Frame 00013.jpg: IoU = 1.00
# Frame 00014.jpg: IoU = 1.00
# Frame 00015.jpg: IoU = 1.00
# Frame 00016.jpg: IoU = 1.00
# Frame 00017.jpg: IoU = 1.00
# Frame 00018.jpg: IoU = 1.00
# Frame 00019.jpg: IoU = 1.00
# Frame 00020.jpg: IoU = 1.00
# Frame 00021.jpg: IoU = 1.00
# Frame 00022.jpg: IoU = 1.00
# Frame 00023.jpg: IoU = 1.00
# Frame 00024.jpg: IoU = 1.00
# Frame 00025.jpg: IoU = 1.00
# Frame 00026.jpg: IoU = 1.00
# Frame 00027.jpg: IoU = 1.00
# Frame 00028.jpg: IoU = 1.00
# Frame 00029.jpg: IoU = 1.00
# Frame 00030.jpg: IoU = 1.00
# Frame 00031.jpg: IoU = 1.00
# Frame 00032.jpg: IoU = 1.00
# ...

# %%
import cv2
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

def load_image(path):
    image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Error: Could not load image at {path}")
    return image

def calculate_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou = np.sum(intersection) / np.sum(union)
    return iou

def display_images(folder, title):
    # Get sorted list of image filenames
    filenames = sorted(os.listdir(folder))
    
    # Load the first and last images
    first_image_path = os.path.join(folder, filenames[0])
    last_image_path = os.path.join(folder, filenames[-1])
    
    first_image = Image.open(first_image_path)
    last_image = Image.open(last_image_path)
    
    # Display the images
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(first_image, cmap='gray')
    plt.title(f'{title} - First Image')
    plt.axis('off')
    
    plt.subplot(1, 2, 2)
    plt.imshow(last_image, cmap='gray')
    plt.title(f'{title} - Last Image')
    plt.axis('off')
    
    plt.show()

# Paths to the ground truth and segmented frames
gt_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\str.bis58"
segmented_folder = r"C:\Users\user1\Desktop\Object_Tracking_Implementation\SAM2\segment-anything-2\notebooks\videos\All_Str.bis58\outputs_street"

# Display images from both folders
display_images(gt_folder, "Ground Truth")
display_images(segmented_folder, "Segmented")

# List of frame filenames
frame_filenames = sorted(os.listdir(gt_folder))

# Threshold for considering an object occluded
iou_threshold = 0.5

# Counter for occluded frames
occluded_frame_count = 0

for frame_filename in frame_filenames:
    gt_path = os.path.join(gt_folder, frame_filename)
    
    # Adjust the filename for the segmented frames
    frame_number = int(frame_filename.split('.')[0])  # Extract the frame number
    segmented_filename = f"frame_{frame_number:04d}.png"  # Match the segmented frame format
    segmented_path = os.path.join(segmented_folder, segmented_filename)

    # Load the ground truth and segmented masks
    gt_mask = load_image(gt_path)
    segmented_mask = load_image(segmented_path)

    # Ensure both masks are loaded
    if gt_mask is None or segmented_mask is None:
        continue

    # Resize the segmented mask to match the ground truth mask size
    if gt_mask.shape != segmented_mask.shape:
        segmented_mask = cv2.resize(segmented_mask, (gt_mask.shape[1], gt_mask.shape[0]))

    # Calculate IoU
    iou = calculate_iou(gt_mask > 0, segmented_mask > 0)
    print(f"Frame {frame_filename}: IoU = {iou:.2f}")  # Debugging output

    # Determine occlusion
    if iou < iou_threshold:
        occluded_frame_count += 1

print(f"Number of occluded frames: {occluded_frame_count}")
# Out:
# Frame 00000.jpg: IoU = 1.00
# Frame 00001.jpg: IoU = 1.00
# Frame 00002.jpg: IoU = 1.00
# Frame 00003.jpg: IoU = 1.00
# Frame 00004.jpg: IoU = 1.00
# Frame 00005.jpg: IoU = 1.00
# Frame 00006.jpg: IoU = 1.00
# Frame 00007.jpg: IoU = 1.00
# Frame 00008.jpg: IoU = 1.00
# Frame 00009.jpg: IoU = 1.00
# Frame 00010.jpg: IoU = 1.00
# Frame 00011.jpg: IoU = 1.00
# Frame 00012.jpg: IoU = 1.00
# Frame 00013.jpg: IoU = 1.00
# Frame 00014.jpg: IoU = 1.00
# Frame 00015.jpg: IoU = 1.00
# Frame 00016.jpg: IoU = 1.00
# Frame 00017.jpg: IoU = 1.00
# Frame 00018.jpg: IoU = 1.00
# Frame 00019.jpg: IoU = 1.00
# Frame 00020.jpg: IoU = 1.00
# Frame 00021.jpg: IoU = 1.00
# Frame 00022.jpg: IoU = 1.00
# Frame 00023.jpg: IoU = 1.00
# Frame 00024.jpg: IoU = 1.00
# Frame 00025.jpg: IoU = 1.00
# Frame 00026.jpg: IoU = 1.00
# Frame 00027.jpg: IoU = 1.00
# Frame 00028.jpg: IoU = 1.00
# Frame 00029.jpg: IoU = 1.00
# Frame 00030.jpg: IoU = 1.00
# Frame 00031.jpg: IoU = 1.00
# Frame 00032.jpg: IoU = 1.00
# ...

# %%
# Example using a hypothetical library for tracking evaluation
from trackeval import Evaluator, HOTA, MOTA

# Initialize evaluator with desired metrics
evaluator = Evaluator(metrics=[HOTA(), MOTA()])

# Load ground truth and predicted tracking results
ground_truth = load_ground_truth_data()
predictions = load_prediction_data()

# Evaluate the tracking results
results = evaluator.evaluate(ground_truth, predictions)

# Print the results
print("HOTA Score:", results['HOTA'])
print("MOTA Score:", results['MOTA'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Example using a hypothetical library for tracking evaluation
# ----> 2 from trackeval import Evaluator, HOTA, MOTA
#       4 # Initialize evaluator with desired metrics
#       5 evaluator = Evaluator(metrics=[HOTA(), MOTA()])
#
# ModuleNotFoundError: No module named 'trackeval'

# %%
import cv2
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

def load_image(path):
    image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Error: Could not load image at {path}")
    return image

def calculate_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou = np.sum(intersection) / np.sum(union)
    return iou

def display_images(folder, title):
    # Get sorted list of image filenames
    filenames = sorted(os.listdir(folder))
    
    # Load the first and last images
    first_image_path = os.path.join(folder, filenames[0])
    last_image_path = os.path.join(folder, filenames[-1])
    
    first_image = Image.open(first_image_path)
    last_image = Image.open(last_image_path)
    
    # Display the images
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(first_image, cmap='gray')
    plt.title(f'{title} - First Image')
    plt.axis('off')
    
    plt.subplot(1, 2, 2)
    plt.imshow(last_image, cmap='gray')
    plt.title(f'{title} - Last Image')
    plt.axis('off')
    
    plt.show()

# Paths to the ground truth and segmented frames
gt_folder = r"C:\Users\user1\Desktop\Thesis OT\OT_implementation\segment-anything-2\notebooks\videos\video5"
segmented_folder = r"C:\Users\user1\Desktop\Thesis OT\OT_implementation\segment-anything-2\notebooks\videos\outputsam2_video5"

# Display images from both folders
display_images(gt_folder, "Ground Truth")
display_images(segmented_folder, "Segmented")

# List of frame filenames
frame_filenames = sorted(os.listdir(gt_folder))

# Threshold for considering an object occluded
iou_threshold = 0.9

# Counter for occluded frames
occluded_frame_count = 0

for frame_filename in frame_filenames:
    gt_path = os.path.join(gt_folder, frame_filename)
    
    # Adjust the filename for the segmented frames
    frame_number = int(frame_filename.split('.')[0])  # Extract the frame number
    segmented_filename = f"frame_{frame_number:04d}.png"  # Match the segmented frame format
    segmented_path = os.path.join(segmented_folder, segmented_filename)

    # Load the ground truth and segmented masks
    gt_mask = load_image(gt_path)
    segmented_mask = load_image(segmented_path)

    # Ensure both masks are loaded
    if gt_mask is None or segmented_mask is None:
        continue

    # Resize the segmented mask to match the ground truth mask size
    if gt_mask.shape != segmented_mask.shape:
        segmented_mask = cv2.resize(segmented_mask, (gt_mask.shape[1], gt_mask.shape[0]))

    # Calculate IoU
    iou = calculate_iou(gt_mask > 0, segmented_mask > 0)
    print(f"Frame {frame_filename}: IoU = {iou:.2f}")  # Debugging output

    # Determine occlusion
    if iou < iou_threshold:
        occluded_frame_count += 1

print(f"Number of occluded frames: {occluded_frame_count}")
# Out:
# Error: Could not load image at C:\Users\user1\Desktop\Thesis OT\OT_implementation\segment-anything-2\notebooks\videos\outputsam2_video5\frame_0115.png
# Error: Could not load image at C:\Users\user1\Desktop\Thesis OT\OT_implementation\segment-anything-2\notebooks\videos\outputsam2_video5\frame_0116.png
# Error: Could not load image at C:\Users\user1\Desktop\Thesis OT\OT_implementation\segment-anything-2\notebooks\videos\outputsam2_video5\frame_0117.png
# Error: Could not load image at C:\Users\user1\Desktop\Thesis OT\OT_implementation\segment-anything-2\notebooks\videos\outputsam2_video5\frame_0118.png
# Error: Could not load image at C:\Users\user1\Desktop\Thesis OT\OT_implementation\segment-anything-2\notebooks\videos\outputsam2_video5\frame_0119.png
# Error: Could not load image at C:\Users\user1\Desktop\Thesis OT\OT_implementation\segment-anything-2\notebooks\videos\outputsam2_video5\frame_0120.png
# ...
